# %% [markdown]
# # IV. Основы сетевого анализа

# %% [markdown]
# ## Темы

# %% [markdown]
# 1. [**Граф улично-дорожной сети**](networkAnalysis_1.ipynb)
#
#    Узнаете, что такое граф улично-дорожной сети и какими свойствами он обладает
#
# 2. [**Сетевой анализ улично-дорожной сети**](networkAnalysis_2.ipynb)
#
#    Научитесь выполнять базовые задачи сетевого анализа: искать кратчайшие пути, анализировать центральность и оценивать связность
#
# 3. [**Сетевой анализ с использованием внешних сервисов**](networkAnalysis_3.ipynb)
#
#    Выполните сетевой анализ с помощью внешних API

# %% [markdown]
# ## Задание: Строим зоны доступности
#
# Каждый модуль заканчивается практическим заданием — этапом проекта **«15-минутный город»**, посвящённого анализу доступности повседневных функций. Проект можно выполнять для любого интересующего вас города.
#
# В этом модуле мы строим зоны **зоны пешеходной доступности 5, 10 и 15 минут** от выбранной категории объектов в исследуемом районе.
#
# Задание оформлено в формате **Jupyter Notebook**, где предложена примерная последовательность шагов его выполнения. Оно доступно на платформе [Boosty](https://boosty.to/bellamir).
#
# Там же размещены видео к каждому блоку и есть возможность задавать вопросы. Поддерживая проект, вы помогаете выпуску открытых материалов.
